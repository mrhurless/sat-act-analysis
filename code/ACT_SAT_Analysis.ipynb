# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The city of Casper, Wyoming has commissioned a team to review nationwide ACT and SAT standardized test data in an effort to identify potential areas of policy improvement.  Casper is the main constituent of the Natrona County School District (NCSD), which is the second largest school district in the state.   The mayor is committed to exploring all opportunities to improve the outcomes for the city's high school students.  Unfortunately, he only had a single spreadsheet with Natrona County ACT information from 2017, which he provided to the team reviewing the data.  The ACT is currently mandatory in Wyoming, but it is possible that the choice of ACT over SAT may be limiting students in some way.  The city is asking for this analysis to determine if they should lobby the state to change to requiring the SAT, if the city should try and fund both tests, or if any other changes, based on the data, are recommended.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# Articles have been written about the merits of one test over the other, but many seem to indicate that there are multiple factors that contribute to making the decision of which test to take.  Both tests are similarly priced, timed, and cover a lot of the same material, but there are some differences as well.  Some of the differences are whether you can use a calculator or not, how many questions are on each test, a dedicated science section in the ACT, among others. ([source](https://www.princetonreview.com/college/sat-act))
#
# According to a [U.S. News & World Report article](https://www.usnews.com/education/best-colleges/articles/act-vs-sat-how-to-decide-which-test-to-take), even with the known differences it is still very difficult to predict how a student will perform on either test.  The article goes on to also quotes an admissions consultant who claims that the number of students taking both tests have increased in the past five to ten years. As with many other articles on the subject, the best guidance provided is to take a full length practice exam for each test to help you decide which one to take.
#
# There are also advocates of taking both tests.  Some reasons stated for this range from simply giving admissions teams more data points about a applicant to ensuring that the student is eligible for as many forms of financial aid as possible.  When it comes to selective schools, even if they are test-optional, if the student's score is near or above the 50th percentile of published scores for that school, it could give the student an edge during the admission process.  [The Princeton Review](https://www.princetonreview.com/college-advice/4-reasons-to-take-both-sat-and-act) even shows in this article that the percent of 2017 college freshman that submitted both could be up to 49%.
#
# Some Casper parents have suggested lobbying the state to switch from the ACT to the SAT, or potentially funding a budget that would cover the costs of both the ACT and the SAT. The mayor prefers to make data-driven decsions, which is why he led the effort to commission a team to provide an analysis in order to help guide policy decisions.
#
# *Sources:*
# - "SAT vs ACT: Which Test is Right for You?" The Princeton Review, [https://www.princetonreview.com/college/sat-act](https://www.princetonreview.com/college/sat-act). Accessed November 2022.
#
# - "4 Reasons to Take BOTH the SAT and ACT" The Princeton Review, [https://www.princetonreview.com/college-advice/4-reasons-to-take-both-sat-and-act](https://www.princetonreview.com/college-advice/4-reasons-to-take-both-sat-and-act). Accessed November 2022.
#
# - Moody, Josh. "ACT vs. SAT: How to Decide Which Test to Take" U.S. News & World Report, 20 March 2021, [https://www.usnews.com/education/best-colleges/articles/act-vs-sat-how-to-decide-which-test-to-take](https://www.usnews.com/education/best-colleges/articles/act-vs-sat-how-to-decide-which-test-to-take). Accessed November 2022.
#
# - "SAT vs. ACT: Which Should I Take?" Coursera, 4 May 2022, [https://www.coursera.org/articles/sat-vs-act](https://www.coursera.org/articles/sat-vs-act). Accessed November 2022.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# In Wyoming, students in grades 3-10 take the Wyoming Test of Proficiency and Progress (WY-TOPP) in English language arts (ELA) and math. Students in grade 11 take the ACT. The Wyoming Department of Education views the ACT standardized tests as indicators of college readiness and student achievement in English, math, reading, science, and writing. These standardized test results are used to help evaluate a school’s strengths and weaknesses, and to produce a school performance rating. ([source](https://edu.wyoming.gov/wp-content/uploads/2022/07/2022-FAQ-Assessment-FINAL.pdf))
#
# The mayor of Casper, also provided a spreadhseet with Natrona County ACT results from 2017.  It does not include participation rate data, but does provide a mean ACT composite score for the grade 11 students tested in 2017.  Their mean composite score was 19.3.

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.

# %% [markdown]
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State.  Includes participation rates, section scores, and composite scores for each state.
#
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State.  Includes participation rates, section scores, and total scores for each state.
#
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges.  Includes data on number of applicants, acceptance rate as well as 25th and 75th percentile information for SAT and ACT scores for their admission.
#
# * [`NCSD_2017.xlsx`](./data/NCSD_2017.xlsx): Data provided by the mayor of Casper with ACT score data from 2017.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calc_mean(value_list):
    ''' fn that takes a list of numeric values and returns the mean.'''
    
    #sum the values in the list:
    value_sum = sum(value_list)
    
    #calculate the mean (sum / number of values)
    value_mean = value_sum / len(value_list)
    
    return value_mean

test_data = [1, 2, 3, 4, 5]
#mean should be 3

calc_mean(test_data)
# Out:
# 3.0

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def calc_stdev(value_list):
    ''' fn that takes a list of values and returns the population standard
    deviation'''
    
    #Calculate the mean and print it
    value_mean = calc_mean(value_list)

    #Calculate the standard deviation
    #Subtract the mean from the values
    diffs = [value - value_mean for value in value_list]

    #Square the differences
    squares = [square ** 2 for square in diffs]

    #Sum the squares
    sq_sum = sum(squares)
    
    #calculate population standard deviation and return
    stdev = (sq_sum/len(value_list)) ** .5
    
    return stdev

# %%
calc_stdev(test_data)
# Out:
# 1.4142135623730951

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Code:
def percent_to_decimal(num_string):
    ''' fn that takes a string that represents a percentage e.g. 50.5% and 
    returns a decimal approximation float value'''
    
    #parse string, cast string to float, and divide by 100
    return float(num_string.strip().replace('%', '')) / 100

# %%
percent_to_decimal('78.9%')
# Out:
# 0.789

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# import for state abbreviation mapping https://pypi.org/project/us/
import us

# try to get a choropleth going
import plotly.express as px

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# #### ACT data import and cleaning

# %%
act = pd.read_csv('../data/act_2017.csv')
act.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# I see an entry for 'National' so check the shape and drop row if state data is there

# %%
act.shape
# Out:
# (52, 7)

# %%
# 50 states and the District of Columbia should be 51, so I will remove the national row
act.drop(0, inplace=True)
act.shape
# Out:
# (51, 7)

# %% [markdown]
# Check for null values

# %%
act.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# Check descriptive stats

# %%
act.describe()
# Out:
#          English       Math    Reading    Science
# count  51.000000  51.000000  51.000000  51.000000
# mean   20.931373  21.182353  22.013725  21.041176
# std     2.353677   1.981989   2.067271   3.182463
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.450000  19.900000
# 50%    20.700000  20.900000  21.800000  21.300000
# 75%    23.300000  23.100000  24.150000  22.750000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# All values are plausible.  Missing participation and composite score data.
#
# Checking data types and correct as needed

# %%
act.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# Convert participation percentage string to decimal values

# %%
act.Participation = act.Participation.apply(percent_to_decimal)

# %%
act.head(2)
# Out:
#      State  Participation  English  Math  Reading  Science Composite
# 1  Alabama           1.00     18.9  18.4     19.7     19.4      19.2
# 2   Alaska           0.65     18.7  19.8     20.4     19.9      19.8

# %%
# check why composite is an object
act.Composite.unique()
# Out:
# array(['19.2', '19.8', '19.7', '19.4', '22.8', '20.8', '25.2', '24.1',
#        '24.2', '21.4', '19.0', '22.3', '22.6', '21.9', '21.7', '20.0',
#        '19.5', '24.3', '23.6', '25.4', '21.5', '18.6', '20.4', '20.3',
#        '17.8', '25.5', '23.9', '19.1', '22.0', '21.8', '23.7', '24.0',
#        '18.7', '20.7', '23.8', '20.5', '20.2x'], dtype=object)

# %% [markdown]
# Looks like there is an odd entry.  Checking to see how many entries might be like this.

# %%
act[act.Composite == '20.2x']
# Out:
#       State  Participation  English  Math  Reading  Science Composite
# 51  Wyoming            1.0     19.4  19.8     20.8     20.6     20.2x

# %% [markdown]
# Remove the errant character

# %%
act.loc[51, 'Composite'] = 20.2

# %% [markdown]
# Check `dtypes` again

# %%
act.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# Change composite to a float and confirm

# %%
act.Composite = act.Composite.astype(float)
act.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# Check describe once again now that we ahve more numeric values

# %%
act.describe()
# Out:
#        Participation    English       Math    Reading    Science  Composite
# count      51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean        0.652549  20.931373  21.182353  22.013725  21.041176  21.519608
# std         0.321408   2.353677   1.981989   2.067271   3.182463   2.020695
# min         0.080000  16.300000  18.000000  18.100000   2.300000  17.800000
# 25%         0.310000  19.000000  19.400000  20.450000  19.900000  19.800000
# 50%         0.690000  20.700000  20.900000  21.800000  21.300000  21.400000
# 75%         1.000000  23.300000  23.100000  24.150000  22.750000  23.600000
# max         1.000000  25.500000  25.300000  26.000000  24.900000  25.500000

# %% [markdown]
# Rename columns

# %%
act.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act.columns = [f'act_{col.lower()}' for col in act.columns]
act.head(3)
# Out:
#   act_state  act_participation  act_english  act_math  act_reading  \
# 1   Alabama               1.00         18.9      18.4         19.7
# 2    Alaska               0.65         18.7      19.8         20.4
# 3   Arizona               0.62         18.6      19.8         20.1
#
#    act_science  act_composite
# 1         19.4           19.2
# 2         19.9           19.8
# 3         19.8           19.7

# %% [markdown]
# #### SAT data import and cleaning

# %%
sat = pd.read_csv('../data/sat_2017.csv')
sat.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %% [markdown]
# Check shape

# %%
sat.shape
# Out:
# (51, 5)

# %% [markdown]
# Check for null values

# %%
sat.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %% [markdown]
# Look at descriptive statistics

# %%
sat.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# Scores do not look correct.
#
# From:https://satsuite.collegeboard.org/sat/scores/understanding-scores/how-scores-are-calculated
#
# Your total score is a number between 400 and 1600. The total score is the sum of the two section scores: Evidence-Based Reading and Writing, and Math. Each of these two section scores has a possible range of 200–800. The Evidence-Based Reading and Writing score is composed of the Reading Test and the Writing and Language Test, and each of those tests contributes equally to the section score. The Math section score is made up of the Math Test only.
#
# Math has a minimum value of 52, which is below the minimum section score possible.

# %%
sat[sat.Math < 200]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %% [markdown]
# This looks to be a simple error.  Since we have writing score and total, we can calculate the math section score.
#
# $1060 - 536 = 524$
#
# Correcting value

# %%
sat.loc[20, 'Math'] = 524
sat.loc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                       524
# Total                                     1060
# Name: 20, dtype: object

# %% [markdown]
# Check descriptive stats once more

# %%
sat.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  556.882353  1126.098039
# std                             45.666901   47.121395    92.494812
# min                            482.000000  468.000000   950.000000
# 25%                            533.500000  523.500000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# Values look plausible now. Checking rest of rows in case.

# %%
sat[sat['Evidence-Based Reading and Writing'] + sat['Math'] != sat['Total']]
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 6     Connecticut          100%                                 530   512
# 7        Delaware          100%                                 503   492
# 12          Idaho           93%                                 513   493
# 15           Iowa            2%                                 641   635
# 18      Louisiana            4%                                 611   586
# 21  Massachusetts           76%                                 555   551
# 22       Michigan          100%                                 509   495
# 24    Mississippi            2%                                 634   607
# 27       Nebraska            3%                                 629   625
# 32       New York           67%                                 528   523
# 35           Ohio           12%                                 578   570
# 39   Rhode Island           71%                                 539   524
# ...

# %% [markdown]
# Many of the totals are one off.  As I'm interested in looking at the section scores, I will drop the total column and then create a new one.

# %%
sat.drop(columns='Total', inplace=True)
sat['total'] = sat['Evidence-Based Reading and Writing'] + sat['Math']

# %%
#check my work
sat[sat['Evidence-Based Reading and Writing'] + sat['Math'] != sat['total']]
# Out:
# Empty DataFrame
# Columns: [State, Participation, Evidence-Based Reading and Writing, Math, total]
# Index: []

# %% [markdown]
# Moving to data types

# %%
sat.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# total                                  int64
# dtype: object

# %% [markdown]
# Participation is listed as an object so applying function to convert to decimal value.

# %%
sat.Participation = sat.Participation.apply(percent_to_decimal)
sat.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# total                                   int64
# dtype: object

# %% [markdown]
# Check and rename columns as necessary.

# %%
sat.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'total'],
#       dtype='object')

# %%
#rename the very long column name, then transform all the column names
sat.rename({'Evidence-Based Reading and Writing': 'read_write'
           }, axis=1, inplace=True)

sat.columns = [f'sat_{col.lower()}' for col in sat.columns]
sat.head(2)
# Out:
#   sat_state  sat_participation  sat_read_write  sat_math  sat_total
# 0   Alabama               0.05             593       572       1165
# 1    Alaska               0.38             547       533       1080

# %% [markdown]
# #### Merge ACT and SAT test data

# %% [markdown]
# Renaming state columns so I can merge the two dataframes

# %%
act.rename({'act_state': 'state'}, axis=1, inplace=True)
sat.rename({'sat_state': 'state'}, axis=1, inplace=True)

# %%
act.head(2)
# Out:
#      state  act_participation  act_english  act_math  act_reading  \
# 1  Alabama               1.00         18.9      18.4         19.7
# 2   Alaska               0.65         18.7      19.8         20.4
#
#    act_science  act_composite
# 1         19.4           19.2
# 2         19.9           19.8

# %%
sat.head(2)
# Out:
#      state  sat_participation  sat_read_write  sat_math  sat_total
# 0  Alabama               0.05             593       572       1165
# 1   Alaska               0.38             547       533       1080

# %% [markdown]
# Merge the dataframes

# %%
act_sat = pd.merge(act, sat, how='left')
act_sat.head()
# Out:
#         state  act_participation  act_english  act_math  act_reading  \
# 0     Alabama               1.00         18.9      18.4         19.7
# 1      Alaska               0.65         18.7      19.8         20.4
# 2     Arizona               0.62         18.6      19.8         20.1
# 3    Arkansas               1.00         18.9      19.0         19.7
# 4  California               0.31         22.5      22.7         23.1
#
#    act_science  act_composite  sat_participation  sat_read_write  sat_math  \
# 0         19.4           19.2               0.05             593       572
# 1         19.9           19.8               0.38             547       533
# 2         19.8           19.7               0.30             563       553
# 3         19.5           19.4               0.03             614       594
# 4         22.2           22.8               0.53             531       524
#
#    sat_total
# 0       1165
# 1       1080
# 2       1116
# 3       1208
# 4       1055

# %% [markdown]
# Checking merged dataframe shape and null values in case something went wrong

# %%
act_sat.shape
# Out:
# (51, 11)

# %%
act_sat.isnull().sum()
# Out:
# state                0
# act_participation    0
# act_english          0
# act_math             0
# act_reading          0
# act_science          0
# act_composite        0
# sat_participation    0
# sat_read_write       0
# sat_math             0
# sat_total            0
# dtype: int64

# %% [markdown]
# Looks good so exporting this.

# %%
act_sat.to_csv('../data/act_sat_clean_2017.csv')

# %% [markdown]
# ### College test data import and cleaning

# %%
tests_by_college = pd.read_csv('../data/sat_act_by_college.csv')
tests_by_college.head(3)
# Out:
#                  School Test Optional? Applies to Class Year(s)  \
# 0   Stanford University            Yes                     2021
# 1       Harvard College            Yes                     2021
# 2  Princeton University            Yes                     2021
#
#                                       Policy Details  Number of Applicants  \
# 0  Stanford has adopted a one-year test optional ...                 47452
# 1  Harvard has adopted a one-year test optional p...                 42749
# 2  Princeton has adopted a one-year test optional...                 35370
#
#   Accept Rate SAT Total 25th-75th Percentile ACT Total 25th-75th Percentile
# 0        4.3%                      1440-1570                          32-35
# 1        4.7%                      1460-1580                          33-35
# 2        5.5%                      1440-1570                          32-35

# %% [markdown]
# Check for null values

# %%
tests_by_college.isnull().sum()
# Out:
# School                             0
# Test Optional?                     0
# Applies to Class Year(s)          26
# Policy Details                     0
# Number of Applicants               0
# Accept Rate                        0
# SAT Total 25th-75th Percentile     0
# ACT Total 25th-75th Percentile     0
# dtype: int64

# %% [markdown]
# Check the shape

# %%
tests_by_college.shape
# Out:
# (416, 8)

# %% [markdown]
# Look at descriptive stats

# %%
tests_by_college.describe()
# Out:
#        Number of Applicants
# count            416.000000
# mean           17481.759615
# std            17447.621897
# min              211.000000
# 25%             5313.000000
# 50%            11622.000000
# 75%            23599.750000
# max           111322.000000

# %% [markdown]
# Checking unique values in test optional column

# %%
tests_by_college['Test Optional?'].unique()
# Out:
# array(['Yes', 'Yes (TB)', 'Yes*', 'Yes (TF)', 'No'], dtype=object)

# %% [markdown]
# Flatten these values to Yes or No

# %%
tests_by_college['Test Optional?'] = ['Yes' if value != 'No' else value 
                             for value in tests_by_college['Test Optional?']]

tests_by_college['Test Optional?'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# #### Check the percentile columns for anything odd

# %%
tests_by_college['SAT Total 25th-75th Percentile'].value_counts()
# Out:
# 1070-1270    6
# --           6
# 1120-1320    5
# 1140-1320    5
# 1150-1360    4
#             ..
# 910-1130     1
# 1060-1320    1
# 1090-1270    1
# 1190-1440    1
# 820-1050     1
# Name: SAT Total 25th-75th Percentile, Length: 286, dtype: int64

# %% [markdown]
# It appears that `--` is used for schools that don't have reported 25-75 percentile scores.
#
# Removing 11 rows with that criteria.

# %%
# create mask and get index
drop_index = tests_by_college[
    (tests_by_college['SAT Total 25th-75th Percentile'] == '--') | 
    (tests_by_college['ACT Total 25th-75th Percentile'] == '--')].index

# %%
tests_by_college.drop(drop_index, inplace=True)

# %% [markdown]
# Checking data types

# %%
tests_by_college.dtypes
# Out:
# School                            object
# Test Optional?                    object
# Applies to Class Year(s)          object
# Policy Details                    object
# Number of Applicants               int64
# Accept Rate                       object
# SAT Total 25th-75th Percentile    object
# ACT Total 25th-75th Percentile    object
# dtype: object

# %% [markdown]
# Convert percentage strings to decimal values

# %%
# apply percent conversion function to accept rate and re-check dtypes
tests_by_college['Accept Rate'
                ] = tests_by_college['Accept Rate'].apply(percent_to_decimal)

tests_by_college.dtypes
# Out:
# School                             object
# Test Optional?                     object
# Applies to Class Year(s)           object
# Policy Details                     object
# Number of Applicants                int64
# Accept Rate                       float64
# SAT Total 25th-75th Percentile     object
# ACT Total 25th-75th Percentile     object
# dtype: object

# %% [markdown]
# Now that these are numeric values, check describe again for the dataframe

# %%
tests_by_college.describe()
# Out:
#        Number of Applicants  Accept Rate
# count            405.000000   405.000000
# mean           17339.239506     0.554116
# std            17187.633091     0.242055
# min              211.000000     0.043000
# 25%             5208.000000     0.374000
# 50%            11478.000000     0.611000
# 75%            23583.000000     0.742000
# max           111322.000000     0.999000

# %% [markdown]
# 99% seems like a high acceptance rate.  Look at those values more closely.

# %%
tests_by_college.sort_values(by='Accept Rate', ascending=False).head()
# Out:
#                              School Test Optional? Applies to Class Year(s)  \
# 415     University of Texas El Paso             No                      NaN
# 389                Western Kentucky            Yes   All / Permanent Policy
# 388  Queens University of Charlotte            Yes   All / Permanent Policy
# 387                  Portland State            Yes   All / Permanent Policy
# 414           University of Wyoming             No                      NaN
#
#                                         Policy Details  Number of Applicants  \
# 415  UTEP requires either the SAT or ACT. It does n...                  7157
# 389  WKU offers a test optional policy for students...                  8245
# 388  Queens University of Charlotte offers a test o...                  2319
# 387  Portland State offers a test optional policy w...                  7821
# 414  University of Wyoming requires either the SAT ...                  5348
#
# ...

# %% [markdown]
# There are multiple schools with very high rates, and I checked the original data source and confirmed there are schools with rates this high.  Moving on.

# %% [markdown]
# #### Rename columns

# %%
# make column names lower case and replace spaces with underscores
tests_by_college.columns = [col.lower().replace(' ', '_') 
                           for col in tests_by_college.columns]

# %%
tests_by_college.columns
# Out:
# Index(['school', 'test_optional?', 'applies_to_class_year(s)',
#        'policy_details', 'number_of_applicants', 'accept_rate',
#        'sat_total_25th-75th_percentile', 'act_total_25th-75th_percentile'],
#       dtype='object')

# %%
#clean other names and prepare for column split
tests_by_college.rename({'test_optional?': 'test_opt',
                        'number_of_applicants': 'applicants',
                        'sat_total_25th-75th_percentile': 'sat_25p',
                        'act_total_25th-75th_percentile': 'act_25p'},
                       axis=1, inplace=True)

# %% [markdown]
# ### Split percentiles
#
# Reference:
# https://stackoverflow.com/questions/37333299/splitting-a-pandas-dataframe-column-by-delimiter
#
# and
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html

# %%
tests_by_college[['sat_25p','sat_75p']
                ] = tests_by_college.sat_25p.str.split('-', expand=True)

# %%
tests_by_college[['act_25p','act_75p']
                ] = tests_by_college.act_25p.str.split('-', expand=True)

# %% [markdown]
# Check unique values to see if only numbers remain

# %%
tests_by_college.sat_25p.unique()
# Out:
# array(['1440', '1460', '1450', '\u200b\u200b 1530', '\u200b\u200b 1500',
#        '\u200b\u200b 1440', '\u200b\u200b 1490', '1390', '1330', '1380',
#        '1360', '1470', '1400', '1410', '1340', '1270', '1290', '1350',
#        '1300', '1490', '1370', '1283', '1320', '1310', '1348', '1180',
#        '1280', '1250', '1260', '1220', '1240', '1333', '1210', '1110',
#        '1255', '1200', '1040', '1030', '1100', '890', '1325', '1150',
#        '1160', '1080', '1230', '1190', '1140', '1020', '990', '1090',
#        '1050', '1130', '1203', '950', '1070', '1170', '910', '1060',
#        '1120', '1142.5', '1045', '1248', '1010', '1078', '940', '1000',
#        '980', '1153', '1012', '1108', '970', '1038', '960', '1143',
#        '1008', '1245', '1275', '793', '820'], dtype=object)

# %% [markdown]
# Get rid of this `\u200b\u200b ` remnant. Check and run on all percentile columns if needed.

# %%
tests_by_college.sat_25p = \
tests_by_college.sat_25p.str.replace('\u200b\u200b ', '')

# %%
tests_by_college.sat_75p.unique()
# Out:
# array(['1570', '1580', '1560', '1540', '1520', '1550', '1510', '1480',
#        '1530', '1490', '1485', '1500', '1440', '1450', '1420', '1470',
#        '1460', '1400', '1380', '1320', '1430', '1390', '1310', '1213',
#        '1410', '1080', '1250', '1350', '1230', '1360', '1270', '1370',
#        '1205', '1290', '1200', '1160', '1260', '1340', '1190', '1130',
#        '1368', '1330', '1345', '1358', '1280', '1225', '1210', '1300',
#        '1240', '1150', '1338', '1090', '1295', '1265', '1269', '1180',
#        '1273', '1170', '1220', '1365', '1140', '1398', '1285', '1465',
#        '1078', '1050'], dtype=object)

# %%
tests_by_college.act_25p.unique()
# Out:
# array(['32', '33', '35', '34', '31', '29', '27', '30', '28', '26', '25',
#        '22', '19', '15', '20', '24', '23', '21', '16', '17', '18', '19.3'],
#       dtype=object)

# %%
tests_by_college.act_75p.unique()
# Out:
# array(['35', '36', '34', '33', '32', '31', '29', '24', '27', '30', '20',
#        '26', '25', '28', '22', '23', '28.5', '19', '25.3'], dtype=object)

# %%
tests_by_college.head(3)
# Out:
#                  school test_opt applies_to_class_year(s)  \
# 0   Stanford University      Yes                     2021
# 1       Harvard College      Yes                     2021
# 2  Princeton University      Yes                     2021
#
#                                       policy_details  applicants  accept_rate  \
# 0  Stanford has adopted a one-year test optional ...       47452        0.043
# 1  Harvard has adopted a one-year test optional p...       42749        0.047
# 2  Princeton has adopted a one-year test optional...       35370        0.055
#
#   sat_25p act_25p sat_75p act_75p
# 0    1440      32    1570      35
# 1    1460      33    1580      35
# 2    1440      32    1570      35

# %% [markdown]
# Checking data types

# %%
tests_by_college.dtypes
# Out:
# school                       object
# test_opt                     object
# applies_to_class_year(s)     object
# policy_details               object
# applicants                    int64
# accept_rate                 float64
# sat_25p                      object
# act_25p                      object
# sat_75p                      object
# act_75p                      object
# dtype: object

# %% [markdown]
# Change data type on percentile columns as float since there were some decimal values.

# %%
#neat trick from https://stackoverflow.com/questions/55833729/how-to-change-datatype-of-multiple-columns-in-pandas

tests_by_college = tests_by_college.astype(
    {col: 'float' for col in ['sat_25p', 'sat_75p', 'act_25p', 'act_75p']})

# %%
tests_by_college.dtypes
# Out:
# school                       object
# test_opt                     object
# applies_to_class_year(s)     object
# policy_details               object
# applicants                    int64
# accept_rate                 float64
# sat_25p                     float64
# act_25p                     float64
# sat_75p                     float64
# act_75p                     float64
# dtype: object

# %% [markdown]
# Calculate median from ACT and SAT percentile data.

# %%
# calculate the ACT median; median of 2 is mean
tests_by_college['act_med'] = (tests_by_college.act_25p + 
                               tests_by_college.act_75p) / 2

# calculate the SAT median; median of 2 is mean
tests_by_college['sat_med'] = (tests_by_college.sat_25p + 
                               tests_by_college.sat_75p) / 2

tests_by_college.head(2)
# Out:
#                 school test_opt applies_to_class_year(s)  \
# 0  Stanford University      Yes                     2021
# 1      Harvard College      Yes                     2021
#
#                                       policy_details  applicants  accept_rate  \
# 0  Stanford has adopted a one-year test optional ...       47452        0.043
# 1  Harvard has adopted a one-year test optional p...       42749        0.047
#
#    sat_25p  act_25p  sat_75p  act_75p  act_med  sat_med
# 0   1440.0     32.0   1570.0     35.0     33.5   1505.0
# 1   1460.0     33.0   1580.0     35.0     34.0   1520.0

# %% [markdown]
# Drop unneeded columns

# %%
tests_by_college.drop(['applies_to_class_year(s)', 
                       'policy_details'], axis=1, inplace=True)

# %% [markdown]
# Export CSV of cleaned data

# %%
tests_by_college.to_csv('../data/tests_by_college_clean.csv')

# %% [markdown]
# ### Data Dictionary
#
# DataFrames:
# - `act_sat` ACT and SAT data from states including scores and participation rates
# - `tests_by_college` College admissions standardized test data

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**act_participation**|*float64*|2017 ACT Scores by State|ACT participation rate for the state|
# |**act_english**|*float64*|2017 ACT Scores by State|ACT English section score (from 1 to 36) |
# |**act_math**|*float64*|2017 ACT Scores by State|ACT Math section score (from 1 to 36) |
# |**act_reading**|*float64*|2017 ACT Scores by State|ACT Reading section score (from 1 to 36) |
# |**act_science**|*float64*|2017 ACT Scores by State|ACT Science section score (from 1 to 36) |
# |**act_composite**|*float64*|2017 ACT Scores by State|ACT Composite score (average of section scores)|
# |**sat_participation**|*float64*|2017 SAT Scores by State|SAT participation rate|
# |**sat_read_write**|*int64*|2017 SAT Scores by State|SAT Evidence-Based Reading and Writing section score (range 200–800)|
# |**sat_math**|*int64*|2017 SAT Scores by State|SAT Math section score range (200–800)|
# |**sat_total**|*int64*|2017 SAT Scores by State|SAT total score between range (400-1600)|
# |**test_opt**|*string*|Ranges of Accepted ACT & SAT Student Scores by Colleges|Indicates if testing is optional (Yes/No)|
# |**applicants**|*int64*|Ranges of Accepted ACT & SAT Student Scores by Colleges|Number of applicants to the school|
# |**accept_rate**|*float64*|Ranges of Accepted ACT & SAT Student Scores by Colleges|Acceptance rate of the school|
# |**sat_25p**|*float64*|Ranges of Accepted ACT & SAT Student Scores by Colleges|25th percentile of total SAT score for School acceptance |
# |**sat_75p**|*float64*|Ranges of Accepted ACT & SAT Student Scores by Colleges|75th percentile of total SAT score for School acceptance |
# |**act_25p**|*float64*|Ranges of Accepted ACT & SAT Student Scores by Colleges|25th percentile of composite ACT score for School acceptance |
# |**act_75p**|*float64*|Ranges of Accepted ACT & SAT Student Scores by Colleges|75th percentile of composite ACT score for School acceptance |
# |**act_med**|*float64*|Ranges of Accepted ACT & SAT Student Scores by Colleges|Calculated median composite ACT score for School acceptance |
# |**sat_med**|*float64*|Ranges of Accepted ACT & SAT Student Scores by Colleges|Calculated median total SAT score for School acceptance |

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Check descriptive statistics of `act_sat`

# %%
act_sat.describe()
# Out:
#        act_participation  act_english   act_math  act_reading  act_science  \
# count          51.000000    51.000000  51.000000    51.000000    51.000000
# mean            0.652549    20.931373  21.182353    22.013725    21.041176
# std             0.321408     2.353677   1.981989     2.067271     3.182463
# min             0.080000    16.300000  18.000000    18.100000     2.300000
# 25%             0.310000    19.000000  19.400000    20.450000    19.900000
# 50%             0.690000    20.700000  20.900000    21.800000    21.300000
# 75%             1.000000    23.300000  23.100000    24.150000    22.750000
# max             1.000000    25.500000  25.300000    26.000000    24.900000
#
#        act_composite  sat_participation  sat_read_write    sat_math  \
# count      51.000000          51.000000       51.000000   51.000000
# mean       21.519608           0.398039      569.117647  556.882353
# std         2.020695           0.352766       45.666901   47.121395
# ...

# %% [markdown]
# Find median for numeric columns

# %%
act_sat.select_dtypes(include='number').median()
# Out:
# act_participation       0.69
# act_english            20.70
# act_math               20.90
# act_reading            21.80
# act_science            21.30
# act_composite          21.40
# sat_participation       0.38
# sat_read_write        559.00
# sat_math              548.00
# sat_total            1106.00
# dtype: float64

# %% [markdown]
# Find mode for numeric columns

# %%
act_sat.select_dtypes(include='number').mode()
# Out:
#    act_participation  act_english  act_math  act_reading  act_science  \
# 0                1.0         19.0      19.4         20.1         20.5
# 1                NaN         19.5       NaN         20.8         20.6
# 2                NaN         21.2       NaN          NaN         20.9
# 3                NaN          NaN       NaN          NaN         22.0
#
#    act_composite  sat_participation  sat_read_write  sat_math  sat_total
# 0           19.8               0.03           513.0     524.0     1116.0
# 1           20.3                NaN           530.0       NaN        NaN
# 2           21.4                NaN             NaN       NaN        NaN
# 3            NaN                NaN             NaN       NaN        NaN

# %% [markdown]
# ### Summary Statistics
# ||ACT Participation|Composite Score|SAT Participation|Total Score|
# |---|---|---|---|---|
# |Mean|.6525 (65.3%)|21.5|.398 (39.8%)|1126|
# |Median|.69 (69%)|21.4|.38 (38%)|1106|
# |Mode|1 (100%)|(19.8, 20.3, 21.4)|.03 (3%)|1116|
# |Spread|.08-1 (8%-100%)|17.8-25.5|.02-1 (2%-100%)|950-1295|
# |Std Dev|.3214 (32.1%)|3.18|.3527 (35.3%)|92.45|

# %% [markdown]
# Both ACT and SAT participation have some similarities in their shapes.  Although the means are ~25 percentage points apart, both have standard deviations of over 30%.  In addition, the range is similar--92% for ACT and 98% for SAT.  This would indicate that the data is quite spread and there isn't really a central tendency or normal distribution here and I would expect quite a bit of variation in these values.  ACT partipication appears to have a left skew because the mean < median.  The SAT data would have right skew because the mean > median. The shape and skew of the ACT data would also be impacted by mode of 100.
#
# The score data is slightly different.  ACT scores have a range of 7.7 points.  With mean of 21.5, a median and modes that aren't too far off, and a standard deviation of 3.18, this would appear closer to a normal distribution than the participation data, and would have a right skew.  The SAT score data similar in that it has a much smaller range (345 points) and the mean median and mode are relatively close to each other.  This should also be a more normal distribution than the participation rate, and would be right skewed like the ACT test data.
#
# We'll take a look at some plots for each of these to see what they look like.

# %%
sns.displot(act_sat,
            x='act_participation',
            binwidth=.05,
            color='navy',
            alpha=0.7
           ).set(xlabel='Participation Rate (%)',
                 ylabel='Number of States',
                title='Distribution of state ACT participation rate');

# %% [markdown]
# The ACT participation rate, as we thought, does not appear to be normally distributed.  This makes sense due to state policies that may require participation.

# %%
sns.displot(act_sat,
            x='sat_participation',
            binwidth=.05,
            color='teal',
            alpha=0.7
           ).set(xlabel='Participation Rate (%)',
                 ylabel='Number of States',
                title='Distribution of state SAT participation rate');

# %% [markdown]
# Similar to the ACT participation, this is not a normal distribution.  The 3% mode is contributing to the large count on the left of the distribution.  This may be caused by very low participation in the SAT from large amount of states that have high or 100% ACT participation.

# %%
sns.displot(act_sat,
            x='act_composite',
            binwidth=.4,
            color='navy',
            alpha=0.7
           ).set(xlabel='ACT Composite Score (mean)',
                 ylabel='Number of States',
                title='Distribution of mean ACT composite scores');

# %% [markdown]
# The ACT composite score distribution is similar to what we thought--it appears to be normally distributed, right skewed, given the median of 21.4 and mean of 21.5.
#
# Going to see if a boxplot might be easier to visualize.

# %%
sns.boxplot(act_sat, 
            x='act_composite',
           ).set(xlabel='ACT Composite Score (mean)', 
                title='Distribution of mean ACT composite scores');

# %% [markdown]
# In the boxplot, you can see the median of 21.4 indicated by the line in the box.  This also shows us there are more values to the right of the median, pulling the mean to the right and confirming this is right skewed.

# %%
sns.displot(act_sat,
            x='sat_total',
            binwidth=25,
            color='teal'
           ).set(xlabel='SAT Total Score (mean)',
                 ylabel='Number of States',
                title='Distribution of mean SAT total scores');

# %% [markdown]
# Like the ACT scores, the SAT total scores appears to be normally distributed and centered around 1050-1075, and is right skewed, confirming what we saw in the summary statistics.

# %% [markdown]
# Check descriptive statistics for `tests_by_college`

# %%
tests_by_college.describe()
# Out:
#           applicants  accept_rate      sat_25p     act_25p      sat_75p  \
# count     405.000000   405.000000   405.000000  405.000000   405.000000
# mean    17339.239506     0.554116  1167.934568   24.739012  1359.644444
# std     17187.633091     0.242055   129.923812    4.136562   111.478484
# min       211.000000     0.043000   793.000000   15.000000  1050.000000
# 25%      5208.000000     0.374000  1070.000000   22.000000  1270.000000
# 50%     11478.000000     0.611000  1150.000000   24.000000  1350.000000
# 75%     23583.000000     0.742000  1250.000000   28.000000  1440.000000
# max    111322.000000     0.999000  1530.000000   35.000000  1580.000000
#
#           act_75p     act_med      sat_med
# count  405.000000  405.000000   405.000000
# mean    29.910617   27.324815  1263.789506
# std      3.158794    3.602606   119.477388
# min     19.000000   17.000000   935.000000
# 25%     28.000000   25.000000  1175.000000
# 50%     30.000000   27.000000  1250.000000
# ...

# %% [markdown]
# Find median for numeric columns

# %%
tests_by_college.select_dtypes(include='number').median()
# Out:
# applicants     11478.000
# accept_rate        0.611
# sat_25p         1150.000
# act_25p           24.000
# sat_75p         1350.000
# act_75p           30.000
# act_med           27.000
# sat_med         1250.000
# dtype: float64

# %% [markdown]
# Find the mode for the numeric columns

# %%
tests_by_college.select_dtypes(include='number').mode()
# Out:
#    applicants  accept_rate  sat_25p  act_25p  sat_75p  act_75p  act_med  \
# 0        6096        0.579   1070.0     22.0   1320.0     30.0     25.0
# 1        7795        0.731      NaN      NaN      NaN      NaN      NaN
# 2       10500          NaN      NaN      NaN      NaN      NaN      NaN
# 3       18948          NaN      NaN      NaN      NaN      NaN      NaN
#
#    sat_med
# 0   1170.0
# 1      NaN
# 2      NaN
# 3      NaN

# %% [markdown]
# ### Summary Statistics
# ||Accept Rate|ACT Median Admission|SAT Median Admission|
# |---|:-:|:-:|:-:|
# |Mean|.554|27.3|1263.8|
# |Median|.611|27|1250|
# |Mode|.58, .73|25|1170|
# |Spread|.04 - .99|17 - 35.5|935 - 1545|
# |Std Dev|.242|3.6|119.5|

# %% [markdown]
# The acceptance rate for the colleges has a fairly large range of 95%. The large standard deviation would indicate there is some variability, with the mean and median indicating this would be left skewed.
#
# The median ACT admissions score's range of 18.5 and standard deviation of 3.6 would indicate there is still some variability, but I would expect this to be normally distributed with right skew.
#
# The median SAT admissions score has a range of 610 with a standard deviation of 119.5.  Again, this would indicate, along with the median and mean values, that this is also normally distributed with a right skew.
#
# Let's plot these to confirm.

# %%
sns.displot(tests_by_college,
            x='accept_rate',
            binwidth=.05,
            aspect=1.2).set(xlabel='Acceptance Rate',
                            ylabel='Count of Colleges',
                            title='Distribution of College Acceptance Rates');

# %% [markdown]
# As the summary indicated, there is certainly some variability in this distribution but appears centered around 70% with a left skew.

# %%
sns.displot(tests_by_college,
            x='act_med',
            bins=20,
            aspect=1.2,
            color='navy',
            alpha=0.7
           ).set(xlabel='Median ACT composite score',
                 ylabel='Number of Colleges',
                title='Colleges by median ACT composite score for admission');

# %% [markdown]
# This looks normally distributed centered around 25.5, with a right skew. I set the bin count to be the same for this plot as well as the next plot for SAT to see if the shapes look similar.

# %%
sns.displot(tests_by_college,
            x='sat_med',
            bins=20,
            aspect=1.2,
            color='teal'
           ).set(xlabel='Median SAT total score',
                 ylabel='Number of Colleges',
                title='Colleges by median SAT total score for admission');

# %% [markdown]
# The SAT median admission score data looks similar to the ACT distribution, which makes sense since I would assume that the colleges try to choose comparable scores between both tests for their admission requirements.  This is centered around ~1250-1260 and also has a right skew.

# %% [markdown]
# Use a dictionary comprehension to apply the standard deviation function you create in part 1 to each numeric column in the dataframe. No loops.
# Assign the output to variable sd as a dictionary where:
# Each column name is now a key
# That standard deviation of the column is the value
# Example Output : {'ACT_Math': 120, 'ACT_Reading': 120, ...}

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_dict.html?highlight=to_dict#pandas.DataFrame.to_dict

# create a variable to hold a dictionary created from only numeric columns
act_sat_num_dict = act_sat.select_dtypes(include='number').to_dict('list')

# dictcomp to create the requested dictionary
act_sat_sd = \
{key: calc_stdev(values) for key, values in act_sat_num_dict.items()}

# repeat for other dataframe
# create a variable to hold a dictionary created from only numeric columns
test_by_coll_num_dict = \
tests_by_college.select_dtypes(include='number').to_dict('list')

# dictcomp to create the requested dictionary
test_by_coll_sd = \
{key: calc_stdev(values) for key, values in test_by_coll_num_dict.items()}

#check my work
act_sat_sd, test_by_coll_sd
# Out:
# ({'act_participation': 0.3182417575123181,
#   'act_english': 2.3304876369363363,
#   'act_math': 1.9624620273436781,
#   'act_reading': 2.0469029314842646,
#   'act_science': 3.151107895464408,
#   'act_composite': 2.000786081581989,
#   'sat_participation': 0.3492907076664507,
#   'sat_read_write': 45.21697020437866,
#   'sat_math': 46.65713364485503,
#   'sat_total': 91.57639048421622},
#  {'applicants': 17166.400676527417,
#   'accept_rate': 0.24175568498775526,
#   'sat_25p': 129.76331270270018,
#   'act_25p': 4.131452261611048,
#   'sat_75p': 111.34077154127958,
#   'act_75p': 3.1548920842724386,
#   'act_med': 3.598155601296105,
#   'sat_med': 119.32979373915883})

# %% [markdown]
# ### Participation Rates
# #### Which states have the highest and lowest participation rates for the SAT and ACT?

# %%
# mask for 100% participation
act_sat.state[act_sat['act_participation'] == 1].unique()
# Out:
# array(['Alabama', 'Arkansas', 'Colorado', 'Kentucky', 'Louisiana',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nevada',
#        'North Carolina', 'Oklahoma', 'South Carolina', 'Tennessee',
#        'Utah', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# The following 17 states have 100% ACT participation rates:
# - Alabama
# - Arkansas
# - Colorado
# - Kentucky
# - Louisiana
# - Minnesota
# - Mississippi
# - Missouri
# - Montana
# - Nevada
# - North Carolina
# - Oklahoma
# - South Carolina
# - Tennessee
# - Utah
# - Wisconsin
# - Wyoming

# %%
# mask to remove states with 100% and return the top 5
act_sat[act_sat['act_participation'] < 1
       ][['state', 'act_participation']
        ].sort_values(by='act_participation', ascending=False).head()
# Out:
#            state  act_participation
# 34  North Dakota               0.98
# 13      Illinois               0.93
# 11        Hawaii               0.90
# 27      Nebraska               0.84
# 41  South Dakota               0.80

# %%
# mask to remove states with 100% and return the bottom 5
act_sat[act_sat['act_participation'] < 1
       ][['state', 'act_participation']
        ].sort_values(by='act_participation').head()
# Out:
#             state  act_participation
# 19          Maine               0.08
# 29  New Hampshire               0.18
# 7        Delaware               0.18
# 39   Rhode Island               0.21
# 38   Pennsylvania               0.23

# %% [markdown]
# Outide of the states that have 100% ACT participation, the states with the highest participation rates are:
# - North Dakota (98%)
# - Illinois (93%)
# - Hawaii (90%)
# - Nebraska (84%)
# - South Dakota (80%)

# %% [markdown]
# States with the lowest ACT participation rates:
# - Maine (8%)
# - New Hampshire (18%)
# - Delaware (18%)
# - Rhode Island (21%)
# - Pennsylvania (23%)

# %%
# return state and sat_participation for top states
act_sat[['state', 'sat_participation']
       ].sort_values(by='sat_participation', ascending=False).head(9)
# Out:
#                    state  sat_participation
# 8   District of Columbia               1.00
# 22              Michigan               1.00
# 6            Connecticut               1.00
# 7               Delaware               1.00
# 29         New Hampshire               0.96
# 19                 Maine               0.95
# 12                 Idaho               0.93
# 9                Florida               0.83
# 21         Massachusetts               0.76

# %%
# return state and sat_participation for lowest states
act_sat[['state', 'sat_participation']
       ].sort_values(by='sat_participation').head(5)
# Out:
#            state  sat_participation
# 34  North Dakota               0.02
# 24   Mississippi               0.02
# 15          Iowa               0.02
# 25      Missouri               0.03
# 44          Utah               0.03

# %% [markdown]
# The following 4 states have 100% SAT participation:
#
# - District of Columbia
# - Michigan
# - Connecticut
# - Delaware
#
# Outside of those, the states with the highest SAT participation rates:
# - New Hampshire (96%)
# - Maine (95%)
# - Idaho (93%)
# - Florida (83%)
# - Massachusetts (76%)

# %% [markdown]
# States with the lowest SAT participation rates:
# - North Dakota (2%)
# - Mississippi (2%)
# - Iowa (2%)
# - Missouri (3%)
# - Utah (3%)

# %%
# https://plotly.com/python/choropleth-maps/
# https://stackoverflow.com/questions/5306756/how-to-print-a-percentage-value-in-python

# %%
# store the state abbreviation
act_sat['st_abbr'] = [us.states.lookup(state).abbr for 
                      state in act_sat.state]

# %%
px.choropleth(act_sat, locations='st_abbr', 
              color='act_participation', 
              locationmode='USA-states', 
              scope='usa', 
              title='ACT Participation by State', 
              labels={'act_participation': 'Participation'}, 
              hover_name='state', 
              hover_data={'act_participation': ':.0%',
                         'st_abbr': False}, 
              height=600,
              width=800)

# %% [markdown]
# The above image shows the ACT participation by state and illustrates how many of the states with the higher rates are in the central part of the country.  Some of the coastal states, and especially the northeast have lower ACT participation.

# %%
px.choropleth(act_sat, locations='st_abbr', 
              color='sat_participation', 
              locationmode='USA-states', 
              scope='usa', 
              title='SAT Participation by State', 
              labels={'sat_participation': 'Participation'}, 
              hover_name='state', 
              hover_data={'sat_participation': ':.0%',
                         'st_abbr': False}, 
              height=600,
              width=800)

# %% [markdown]
# The above image shows the SAT participation rates appear higher on the coasts, and especially in the northeast.  When compared to the previous image with the ACT participation rates, you they indicate certain regional preferences for the SAT or ACT.

# %% [markdown]
# ### Mean Test Scores
# #### Which states have the highest and lowest mean total/composite scores for the SAT and ACT?

# %%
# view top 5 ACT composite scores
act_sat[['state', 'act_composite']
       ].sort_values(by='act_composite', ascending=False).head()
# Out:
#                    state  act_composite
# 29         New Hampshire           25.5
# 21         Massachusetts           25.4
# 6            Connecticut           25.2
# 19                 Maine           24.3
# 8   District of Columbia           24.2

# %%
# view bottom 5 ACT composite scores
act_sat[['state', 'act_composite']
       ].sort_values(by='act_composite', ascending=True).head()
# Out:
#              state  act_composite
# 28          Nevada           17.8
# 24     Mississippi           18.6
# 40  South Carolina           18.7
# 11          Hawaii           19.0
# 33  North Carolina           19.1

# %% [markdown]
# #### ACT Mean Scores
# State (mean score 1-36)
#
# **ACT highest mean composite scores:**
# - New Hampshire (25.5)
# - Massachusetts (25.4)
# - Connecticut (25.2)
# - Maine (24.3)
# - District of Columbia (24.2)
#
# **ACT lowest mean composite score:**
# - Nevada (17.8)
# - Mississippi (18.6)
# - South Carolina (18.7)
# - Hawaii (19.0)
# - North Carolina (19.1)

# %%
# view top 5 SAT total scores
act_sat[['state', 'sat_total']
       ].sort_values(by='sat_total', ascending=False).head()
# Out:
#         state  sat_total
# 23  Minnesota       1295
# 49  Wisconsin       1291
# 15       Iowa       1276
# 25   Missouri       1271
# 16     Kansas       1260

# %%
# view bottom 5 SAT total scores
act_sat[['state', 'sat_total']
       ].sort_values(by='sat_total', ascending=True).head()
# Out:
#                    state  sat_total
# 8   District of Columbia        950
# 7               Delaware        995
# 22              Michigan       1004
# 12                 Idaho       1006
# 19                 Maine       1012

# %% [markdown]
# #### SAT Mean Scores
# State (mean score 400-1600)
#
# **SAT highest mean total scores:**
# - Minnesota (1295)
# - Wisconsin (1291)
# - Iowa (1276)
# - Missouri (1271)
# - Kansas (1260)
#
# **SAT lowest mean total score:**
# - District of Columbia (950)
# - Delaware (995)
# - Michigan (1004)
# - Idaho (1006)
# - Maine (1012)

# %% [markdown]
# ### Other Participation Rate and Scores Data
#
# - Do any states show have >50% participation on both tests each year?
# - What are their mean scores for both tests?

# %%
# find rows that have both ACT and SAT participation rates above 50%
both_fifty = act_sat[(act_sat.act_participation > .5) & 
                     (act_sat.sat_participation > .5)]

both_fifty['state']
# Out:
# 9     Florida
# 10    Georgia
# 11     Hawaii
# Name: state, dtype: object

# %% [markdown]
# **Florida, Georgia, and Hawaii** are the only states that have above 50% participation on both the ACT and SAT.

# %%
# find the mean scores for these states that have above 50% participation
# on both tests

round(both_fifty['act_composite'].mean(), 1),\
round(both_fifty['sat_total'].mean(), 1)
# Out:
# (20.1, 1050.7)

# %% [markdown]
# For the three states that have above 50% participation on both tests, the mean scores are:
# - **ACT composite:** 20.1
# - **SAT total:** 1050.7

# %% [markdown]
# What is the mean ACT composite score for states that have 100% SAT participation?

# %%
act_sat.act_composite[act_sat.sat_participation == 1].mean()
# Out:
# 24.4

# %% [markdown]
# What is the ACT composite score for states with < 100% SAT participation?

# %%
act_sat.act_composite[(act_sat.sat_participation < 1)].mean()
# Out:
# 21.27446808510638

# %% [markdown]
# What is the SAT total score mean for states wth < 100% SAT participation?

# %%
act_sat.sat_total[(act_sat.sat_participation < 1)].mean()
# Out:
# 1136.9148936170213

# %% [markdown]
# ### College Admittance Data
# - Which colleges have the highest median SAT and ACT scores for admittance?
# - What is the mean of the median SAT and ACT scores of all colleges on this list?

# %%
# return top 5 results based on median ACT score
tests_by_college.sort_values(by='act_med', ascending=False).head()
# Out:
#                                    school test_opt  applicants  accept_rate  \
# 5      California Institute of Technology      Yes        8367        0.064
# 6   Massachusetts Institute of Technology      Yes       21706        0.067
# 18               Johns Hopkins University      Yes       29129        0.106
# 15                Northwestern University      Yes       40585        0.091
# 37             Carnegie Mellon University      Yes       27634        0.154
#
#     sat_25p  act_25p  sat_75p  act_75p  act_med  sat_med
# 5    1530.0     35.0   1560.0     36.0     35.5   1545.0
# 6    1500.0     34.0   1570.0     36.0     35.0   1535.0
# 18   1470.0     33.0   1560.0     35.0     34.0   1515.0
# 15   1440.0     33.0   1550.0     35.0     34.0   1495.0
# 37   1460.0     33.0   1560.0     35.0     34.0   1510.0

# %%
# Retrieve list of schools tied at 34
tests_by_college[tests_by_college.act_med == 34]['school']
# Out:
# 1                Harvard College
# 3            Columbia University
# 4                Yale University
# 7               Brown University
# 8          University of Chicago
# 10    University of Pennsylvania
# 13               Duke University
# 15       Northwestern University
# 16         Vanderbilt University
# 18      Johns Hopkins University
# 20               Rice University
# 31           Harvey Mudd College
# 37    Carnegie Mellon University
# Name: school, dtype: object

# %% [markdown]
# #### Colleges with highest median ACT scores for admittance
# College (median score 1-36)
# - California Institute of Technology (35.5)
# - Massachusetts Institute of Technology (35.0)
#
# The following colleges are all tied for third with a median score of 34.0:
# - Harvard College
# - Columbia University
# - Yale University
# - Brown University
# - University of Chicago
# - University of Pennsylvania
# - Duke University
# - Northwestern University
# - Vanderbilt University
# - Johns Hopkins University
# - Rice University
# - Harvey Mudd College
# - Carnegie Mellon University

# %%
# return top 5 results based on median SAT score
tests_by_college.sort_values(by='sat_med', ascending=False).head()
# Out:
#                                    school test_opt  applicants  accept_rate  \
# 5      California Institute of Technology      Yes        8367        0.064
# 6   Massachusetts Institute of Technology      Yes       21706        0.067
# 31                    Harvey Mudd College      Yes        4045        0.137
# 8                   University of Chicago      Yes       32283        0.073
# 35     Washington University in St. Louis      Yes       31320        0.150
#
#     sat_25p  act_25p  sat_75p  act_75p  act_med  sat_med
# 5    1530.0     35.0   1560.0     36.0     35.5   1545.0
# 6    1500.0     34.0   1570.0     36.0     35.0   1535.0
# 31   1490.0     33.0   1570.0     35.0     34.0   1530.0
# 8    1490.0     33.0   1570.0     35.0     34.0   1530.0
# 35   1470.0     32.0   1570.0     35.0     33.5   1520.0

# %%
# checking to see if there is a tie at 1520
tests_by_college[tests_by_college.sat_med == 1520]['school']
# Out:
# 1                        Harvard College
# 35    Washington University in St. Louis
# Name: school, dtype: object

# %% [markdown]
# #### Colleges with highest median SAT scores for admittance
# College (median score 400-1600)
# - California Institute of Technology (1545)
# - Massachusetts Institute of Technology (1535)
# - Harvey Mudd College (1530)
# - University of Chicago (1530)
#
# The following colleges are all tied for fifth with a median score of 1520:
# - Harvard College
# - Washington University in St. Louis

# %%
# get the mean of all median scores
tests_by_college.act_med.mean(), tests_by_college.sat_med.mean()
# Out:
# (27.324814814814815, 1263.7895061728395)

# %% [markdown]
# Looking across all the schools in the data we have, the mean of the median test scores for admittance:
# - ACT: 27.3
# - SAT: 1263.8

# %% [markdown]
# Using the national score means, how many colleges would they be equal to, or above, the median?
# - How does this change for states with 100% participation in one of the tests?
# - What about for states that don't have 100% participation in either of the tests?

# %%
# count of colleges where national ACT mean >= college median and 
natl_act = tests_by_college[round(act_sat.act_composite.mean(), 1) >= 
                            tests_by_college['act_med']
                            ].school.count()
natl_act
# Out:
# 21

# %%
# divide by count of schools
natl_act / tests_by_college.school.count()
# Out:
# 0.05185185185185185

# %% [markdown]
# Having the national mean ACT score of 21.5 would be equal to or above the median admission score for 21 colleges (5.2%)

# %%
act_sat.sat_total.mean()
# Out:
# 1126.0

# %%
# count of colleges where national SAT mean >= college median
natl_sat = tests_by_college[ round(act_sat.sat_total.mean(), 1) >= 
                            tests_by_college['sat_med']
                            ].school.count()

natl_sat
# Out:
# 48

# %%
# divide by count of schools
natl_sat / tests_by_college.school.count()
# Out:
# 0.11851851851851852

# %% [markdown]
# Having the national mean SAT score of 1126 would be equal to or above the median admission score for 48 colleges (11.9%)

# %%
act_sat.act_composite[(act_sat.act_participation < 1) & 
                      (act_sat.sat_participation < 1)
                     ].mean()
# Out:
# 22.14666666666666

# %%
# for states without 100% participation in either test
# count of colleges where ACT mean >= college median
act_excl_full = tests_by_college[
    round(act_sat.act_composite[
        (act_sat.act_participation < 1) & (act_sat.sat_participation < 1)
    ].mean(), 1) >= tests_by_college['act_med']].school.count()

act_excl_full
# Out:
# 30

# %%
# divide by count of schools
act_excl_full / tests_by_college.school.count()
# Out:
# 0.07407407407407407

# %% [markdown]
# In states without 100% participation in either test, the mean ACT score of 22.2 would be equal to or above the median admission score for 30 colleges (7.4%)

# %%
# for states without 100% participation in either test
# count of colleges where SAT mean >= college median
sat_excl_full = tests_by_college[ 
    act_sat.sat_total[(act_sat.act_participation < 1) &
                     (act_sat.sat_participation < 1)].mean() >= 
    tests_by_college['sat_med']].school.count()

sat_excl_full
# Out:
# 25

# %%
# divide by count of schools
sat_excl_full / tests_by_college.school.count()
# Out:
# 0.06172839506172839

# %% [markdown]
# In states without 100% participation in either test, the mean SAT score of 1104 would be equal to or above the median admission score for 25 colleges (6.2%)

# %%
# for states with 100% participation in ACT
# count of colleges where ACT mean >= college median
act_full = tests_by_college[
    act_sat.act_composite[(act_sat.act_participation == 1)].mean() >= 
    tests_by_college['act_med']].school.count()

act_full
# Out:
# 8

# %%
# divide by count of schools
act_full / tests_by_college.school.count()
# Out:
# 0.019753086419753086

# %% [markdown]
# In states with 100% ACT participation, the mean score is 19.7 and would be equal to or above the median admission score for 8 colleges (2%)

# %%
act_sat.sat_total[(act_sat.sat_participation == 1)].mean()
# Out:
# 997.75

# %%
# for states with 100% participation in SAT
# count of colleges where SAT mean >= college median
sat_full = tests_by_college[ 
    act_sat.sat_total[(act_sat.sat_participation == 1)].mean() >= 
    tests_by_college['sat_med']].school.count()

sat_full
# Out:
# 3

# %%
# divide by count of schools
sat_full / tests_by_college.school.count()
# Out:
# 0.007407407407407408

# %% [markdown]
# In states with 100% SAT participation, the mean score is 997.75 and would be equal to or above the median admission score for 3 colleges (0.7%)

# %% [markdown]
# ### Wyoming Data
# - How do Wyoming test scores compare to the national mean scores?
# - How do Wyoming test scores compare to other states with 100% ACT participation?
# - How do Wyoming test scores comapre to states that don't mandate ACT participation?
# - Based on Wyoming mean ACT scores, what percent of colleges do those scores fall in their 25th-75th percentile scores?
#     - What about their SAT scores?

# %%
# retrieve Wyoming data
act_sat[act_sat['state'] == 'Wyoming']
# Out:
#       state  act_participation  act_english  act_math  act_reading  \
# 50  Wyoming                1.0         19.4      19.8         20.8
#
#     act_science  act_composite  sat_participation  sat_read_write  sat_math  \
# 50         20.6           20.2               0.03             626       604
#
#     sat_total st_abbr
# 50       1230      WY

# %% [markdown]
# #### Wyoming's mean ACT composite score is 20.2 (scale of 1-36)
# - Lower than the national mean of 21.5
# - Between the national 25th percentile (19.8) and 50th percentile (21.4)
#
# #### Natrona County's (Casper) mean ACT composite score is 19.3 (scale of 1-36)
# (see data files for source)
# - Casper underperforms the national mean score and the state's mean score.
#
# #### Wyoming's mean SAT total score is 1230 (scale of 400-1600)
# - Higher than the national mean of 1126
# - Above the national 75th percentile (1211.5)
# - SAT participation rate for Wyoming is 3%

# %%
#create a simple dataframe from a dictionary to create a plot
casper_act = pd.DataFrame({'location': 
                           ['Natrona County', 
                            'Wyoming', 
                            'National', 
                            'Nevada (low)', 
                            'New Hampshire (high)'],
                           'act_comp_mean': [19.3, 20.2, 21.5, 17.8, 25.5]})

sns.catplot(casper_act, 
            x='location',
            y='act_comp_mean',
            kind='bar').set(ylim=(10,28), 
                            ylabel='ACT Composite score mean',
                            xlabel=None,
                            title='Casper ACT composite score mean comparison');

plt.xticks(rotation=30);

# %% [markdown]
# The image above shows Natrona County's ACT composite mean score compared to the state of Wyoming, the National mean as well as the lowest (Nevada) and highest (New Hampshire) mean scores of any states.

# %%
# mandatory ACT subset
mand_act = act_sat[act_sat['act_participation'] == 1]

# descriptive stats on states with mandatory ACT testing
mand_act.describe()
# Out:
#        act_participation  act_english   act_math  act_reading  act_science  \
# count               17.0    17.000000  17.000000    17.000000    17.000000
# mean                 1.0    18.970588  19.388235    20.147059    19.935294
# std                  0.0     1.041492   0.926608     0.938827     0.889481
# min                  1.0    16.300000  18.000000    18.100000    18.200000
# 25%                  1.0    18.500000  18.800000    19.700000    19.400000
# 50%                  1.0    19.400000  19.300000    20.100000    19.900000
# 75%                  1.0    19.600000  19.900000    20.800000    20.600000
# max                  1.0    20.400000  21.500000    21.800000    21.600000
#
#        act_composite  sat_participation  sat_read_write    sat_math  \
# count      17.000000          17.000000       17.000000   17.000000
# mean       19.735294           0.112353      604.411765  590.588235
# std         0.911003           0.154941       36.851151   40.059423
# ...

# %% [markdown]
# #### Wyoming compared to states with 100% ACT participation
#
# ACT:
# - Wyoming mean score: 20.2 (close to 75th percentile)
# - Mandated states mean score: 19.7
# - Highest score in mandated states: 21.5
#
# SAT:
# - Wyoming mean score: 1230
# - Mandated ACT states mean score: 1195
# - Highest score in mandated ACT states: 1295
# - Mean SAT participation rate: 11.2%

# %%
# non-mandatory ACT subset
non_mand_act = act_sat[act_sat['act_participation'] < 1]

# descriptive stats on states with non-mandatory ACT testing
non_mand_act.describe()
# Out:
#        act_participation  act_english   act_math  act_reading  act_science  \
# count          34.000000    34.000000  34.000000    34.000000    34.000000
# mean            0.478824    21.911765  22.079412    22.947059    21.594118
# std             0.251466     2.212878   1.745953     1.831746     3.743920
# min             0.080000    17.800000  19.200000    19.200000     2.300000
# 25%             0.290000    20.750000  20.900000    21.675000    21.000000
# 50%             0.365000    21.550000  21.850000    22.800000    22.050000
# 75%             0.685000    23.800000  23.400000    24.575000    23.475000
# max             0.980000    25.500000  25.300000    26.000000    24.900000
#
#        act_composite  sat_participation  sat_read_write    sat_math  \
# count      34.000000          34.000000       34.000000   34.000000
# mean       22.411765           0.540882      551.470588  540.029412
# std         1.823211           0.337409       39.227569   41.331978
# ...

# %% [markdown]
# #### Wyoming compared to states without 100% ACT participation
#
# ACT:
# - Wyoming mean score: 20.2 (below 25th percentile)
# - Non-mandated states mean ACT score: 22.4
# - Highest score in non-mandated ACT states: 25.5
# - Mean ACT participation rate: 47.9%
#
# SAT:
# - Wyoming mean score: 1230 (well above 75th percentile)
# - Non-mandated ACT states mean SAT score: 1091.5
# - Highest score in non-mandated ACT states: 1276
# - Mean SAT participation rate: 54.1%

# %%
# calculate % of schools where Wyo mean is above median
# total count of schools
total_schools = tests_by_college.school.count()

# count of ACT colleges where Wyo >= act_med
schools_act_med = tests_by_college[ 
    float(act_sat[act_sat.state == 'Wyoming']['act_composite']) >= 
    tests_by_college['act_med']
                              ].school.count()

# count of SAT colleges where Wyo >= sat_med
schools_sat_med = tests_by_college[ 
    float(act_sat[act_sat.state == 'Wyoming']['sat_total']) >= 
    tests_by_college['sat_med']
                              ].school.count()


print(f'Total schools: {total_schools}\n\
Number of ACT schools where score above median: {schools_act_med}\n\
Percent of schools: {schools_act_med / total_schools * 100:.1f}%\n\n\
Number of SAT schools where score above median: {schools_sat_med}\n\
Percent of schools: {schools_sat_med / total_schools * 100:.1f}%')
# Out:
# Total schools: 405
# Number of ACT schools where score above median: 11
# Percent of schools: 2.7%
#
# Number of SAT schools where score above median: 177
# Percent of schools: 43.7%

# %%
# run once more just for Casper ACT of 19.3 since it doesn't exist in the dataframe
# count of ACT colleges where 19.3 >= act_med
casper_act_med = tests_by_college[ 19.3 >= tests_by_college['act_med']
                                  ].school.count()

print(
    f'Number of ACT schools where score above median: {schools_act_med}\n'
    f'Percent of schools: {casper_act_med / total_schools * 100:.1f}%\n'
)
# Out:
# Number of ACT schools where score above median: 11
# Percent of schools: 1.5%

# %% [markdown]
# - Wyoming mean ACT composite scores are above the median for admittance in 11 of the 405 (2.7%) schools.
# - Natrona County mean ACT composite scores are above the median for admisttance in 6 of the 405 (1.5%) schools.
# - Wyoming mean SAT total scores are above the median for admittance in 168 the 405 (41.5%) schools.

# %% [markdown]
# ### Findings
# #### Participation and Mean Scores
# - The states with the 3 lowest ACT participation rates are among the highest in SAT participation
# - Conversely, 4 out of the 5 lowest SAT participation rates below to states with the highest participation rates
# - The lowest rates of SAT participation are in much lower range (2-3%) compared to ACT lowest rates (8-23%)
# - ACT appears to be a more popular test if you take into account:
#     - The number of 100% participation states (17 vs. 4)
#     - The higher range of partipation rates even among the lowest participating states
# - For either test, some higher scoring states have lower participation rates
# - Conversely, some of the lower scoring states have the highest (or mandatory) participation
# - The three states with participation rates above 50% for both tests have mean ACT and SAT scores below the national mean
#    - ACT mean: 20.1
#    - SAT mean: 1050.7
#
# ##### Mean Score Comparison
# - ACT Composite Score Mean
#     - National: 21.5
#     - Natrona County: 19.3
#     - Wyoming: 20.2
#     - States with 100% ACT participation: 19.7
#     - States with < 100% ACT participation: 22.4
#     - States with 100% SAT participation: 24.4
#     - States with < 100% SAT participation: 21.3
# - SAT Total Score Mean
#     - National: 1126
#     - Wyoming: 1230
#     - States with 100% ACT participation: 1195
#     - States with < 100% ACT participation: 1091.5
#     - States with 100% SAT participation: 997.75
#     - States with < 100% SAT participation: 1136.9

# %% [markdown]
# #### College admissions
# - 405 schools listed
# - Cali. Institute of Technology and Massachusetts Institue of Technology have the highest median scores for both ACT and SAT for admission
# - Mean of all schools' median scores for admission:
#     - ACT: 27.3
#     - SAT : 1263.8
# - Based on the median test scores for admission:
#     - The national mean ACT score of 21.5 would be equal to or above 21 colleges (5.2%)
#     - The national mean SAT score of 1126 would be equal to or above the median admission score for 48 colleges (11.9%)
#     - States without 100% participation in either test:
#         - The mean ACT score of 22.2 would be equal to or above 30 colleges (7.4%)
#         - The mean SAT score of 1104 would be equal to or above 25 colleges (6.2%)
#     - States with 100% ACT participation, the mean ACT score of 19.7 would be equal to or above 8 colleges (2%)
#     - States with 100% SAT participation, the mean SAT score of 997.75 would be equal to or above 3 colleges (0.7%)
#     - Wyoming mean ACT score of 20.2 would be equal to or above 11 colleges (2.7%)
#     - Natrona County mean ACT scores of 19.3 would be equal to of above 6 colleges (1.5%)
#     - Wyoming mean SAT score of 1230 would be equal to of above 168 colleges (41.5%)
#
# States without 100% participation in either test have mean test scores that are equal to, or above more colleges when compared to mean ACT scores for states that have 100% ACT participation or mean SAT scores for states that have 100% SAT participation. It is possible that states with 100% participation may be requiring students who are not interested in the test(s) to take them, and other reasons why there seems to be a relationship here.

# %% [markdown]
# ## Data Visualization

# %%
# create Seaborn heatmap with state testing data
sns.heatmap(act_sat.corr(), 
            cmap='rocket', 
            annot=True).set(
    title='Correlation of State Participation and Test Data');

# %% [markdown]
# The above heatmap shows SAT participation rates have a fairly strong positive correlation with most ACT section and composite scores, with the exception of science. In addition, ACT participation also has a strong positive correlation with SAT scores.

# %%
# create Seaborn heatmap with college admission testing data
sns.heatmap(tests_by_college.corr(), 
            cmap='rocket', 
            annot=True).set(
    title='Correlation of College Admission Data');

# %% [markdown]
# This heatmap shows that acceptance rates have a strong negative correlation with test scores.  It also shows that the number of applicants has a negative correlation with the acceptance rate.

# %%
sns.relplot(act_sat,
           y='act_composite',
           x='act_participation',
           kind='scatter',
           aspect=1.3).set(xlabel='ACT participation rate',
                           ylabel='ACT composite score mean',
                           title='ACT participation vs ACT composite mean score');

# plot national average score
plt.axhline(21.5, ls='--', c='orange');

# %% [markdown]
# The image above shows the relationship between ACT participation rates and test scores.  When participation rates go up, the mean score tends to be lower.

# %%
sns.relplot(act_sat,
           y='sat_total',
           x='sat_participation',
           kind='scatter',
           aspect=1.3).set(xlabel='SAT participation rate',
                           ylabel='SAT total score mean',
                           title='SAT participation and SAT total mean score');

# plot national average score
plt.axhline(1126, ls='--', c='orange');

# %% [markdown]
# On the correlation heatmap, we observed correlation between SAT participation and ACT scores, and vice versa.  Exploring that a bit further:

# %%
sns.relplot(act_sat[act_sat.sat_participation > .2],
           y='act_composite',
           x='sat_participation',
           kind='scatter',
           aspect=1.3).set(xlabel='SAT participation rate',
                           ylabel='ACT composite score mean',
                           title='SAT participation and ACT composite mean scores');

# %% [markdown]
# When looking at this data, I'm focusing on SAT participation rates above 20% in order to filter off the lowest participating states, which corresond with the highest ACT taking states.  There does seem to be a linear relationship between the two that indicates that the higher the SAT participation rate is, the higher ACT scores rise.
#
# Trying another plot on this data to illustrate the relationship:

# %%
sns.lmplot(act_sat[act_sat.sat_participation > .2],
           y='act_composite',
           x='sat_participation',
           # kind='scatter',
           aspect=1.3).set(xlabel='SAT participation rate',
                           ylabel='ACT composite score mean',
                           title='SAT participation and ACT composite mean scores');

# %% [markdown]
# The above image plots the relationship between SAT participation rates and ACT composite mean scores.  This plot includes a simple linear regression line to help illustrate the strength and direction of the relationship.

# %%
sns.relplot(act_sat[act_sat.act_participation < 1],
           y='sat_total',
           x='act_participation',
           kind='scatter',
           aspect=1.3).set(xlabel='ACT participation rate',
                           ylabel='SAT total score mean',
                           title='ACT participation and SAT total mean score');

# %% [markdown]
# As with the SAT participation vs. ACT score, in this plot, I am looking at the states where the ACT participation is not 100%.  The above image is showing the relationship between ACT participation rates and SAT total mean scores.  There also appears to be a linear relationship here.

# %%
sns.lmplot(act_sat[act_sat.act_participation < 1],
           y='sat_total',
           x='act_participation',
           aspect=1.3).set(xlabel='ACT participation rate',
                           ylabel='SAT total score mean',
                           title='ACT participation and SAT total mean score');

# %% [markdown]
# The above image is showing the relationship between ACT participation rates and SAT total mean scores. This plot includes a simple linear regression line to help illustrate the strength and direction of the relationship.

# %% [markdown]
# Similarly, the image above shows the relationship between participation SAT rates and test scores.  When participation rates go up, the mean score tends to be lower.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# 1. Most states have a clear preference for one test over the other. The ACT has an overall participation rate higher than the SAT, but there appears to be a regional preference as well.
#     - ACT participation is high in the central part of the United States.
#     - SAT participation is higher in mostly coastal states, especially the northeast.
# 1. Some states with the highest participation rates, especially 100% participation, underperformed the national average scores by quite a bit. For either test, the highest mean scores were produced by states with the lowest participation rates.
# 1. Wyoming's mean scores are below the national average ACT score, but above average for the SAT. However, when compared to other states with 100% ACT participation, Wyoming outperforms those states on both tests.
#     - For Natrona County & Casper, based on ACT scores (no data for SAT), they would be at or above the median for
#     - Based on their ACT scores, they would be at or above the median test score for 2.7% of colleges reviewed.
#     - Based on their SAT scores, they would be at or above the median test score for 43.7% colleges reviewed.
#
# Recommendations drawn from these conclusions:
# - There was no evidence that pointed to a clear advantage in picking the SAT over the ACT.  Both tests are widely accepted by colleges and cover many of the same materials.
# - Further, no evidence indicated that additionally requiring the SAT would improve testing scores, as it was found that states with 100% participation rates performed worse on the required test compared to the national mean.
#     - There are no states that have 100% participation in both tests.  The three states that have high participation in both underperform compared to the national and Wyoming mean scores.
# - While the ACT is still required, adding the ability for students to additionally take the SAT may improve ACT scores.  This would also allow students that are seeking post-secondary education opportunities to take advantage of some of the benefits outlined by the referenced articles, as to not limit any potential opportunities for students:
#     - High scores (if received) could be a differentiator for college admission.
#     - Certain financial aid may require standardized test scores even if the college does not.
#     - Provides college admissions personnel more data about the applicant.
# - Wyoming should consider a study on removing the ACT test mandate.  As stated above, overall mean test scores tend to fall below national performance with states that have 100% participation rates. Since Wyoming has it's own standardized test to measure school performance statewide, removing the ACT requirement should not interfere with other outcome related policy and decisions.
